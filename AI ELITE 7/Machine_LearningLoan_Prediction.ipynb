# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import sidetable

# get the output for all commands

sns.set_style('whitegrid')
plt.style.use('bmh')

import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# for HD visualizations
# %config InlineBackend.figure_format='retina'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 import pandas as pd
#       4 import matplotlib.pyplot as plt
# ----> 5 import seaborn as sns
#       6 import sidetable
#       8 # get the output for all commands
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
loan_df = pd.read_csv(r"C:\Users\psath\Downloads\Machine Learning(Loan Prediction)\credit_risk_dataset.csv",skipinitialspace = True)

# %%
loan_df

# %%
loan_df.describe()

# %% [markdown]
# ## Checking for Duplicates

# %%
loan_df.duplicated()
loan_df.duplicated().value_counts()

# %%
# Dataframe indexing
loan_df[loan_df.duplicated()]

# %%
loan_df.drop_duplicates(keep = 'first', inplace = True)

# %%
loan_df

# %% [markdown]
# ## Identifying Null Values

# %%
loan_df.info()

# %% [markdown]
# **There are some null values in person_emp_length and loan_int_rate column**

# %%
loan_df[loan_df.person_emp_length.isna()]

# %%
loan_df[loan_df.loan_int_rate.isna()]

# %%
loan_df.person_emp_length = loan_df.person_emp_length.fillna(loan_df.person_emp_length.median())

# %%
loan_df.loan_int_rate = loan_df.loan_int_rate.fillna(loan_df.loan_int_rate.median())

# %%
loan_df.isna().sum()

# %% [markdown]
# ## Identify Corrupted Data

# %%
loan_df.info()

# %% [markdown]
# ## Identify the Outliers

# %%
plt.figure(figsize=(15,5))

plt.subplot(121)
sns.boxplot(loan_df.person_age )

# %%
Q1, Q2, Q3 = tuple(loan_df.person_age .quantile(q = [0.25,0.5,0.75]).values)
print(Q1, Q2, Q3)
IQR = Q3-Q1
UL = Q3 + 1.5*IQR
LL = Q1-1.5*IQR

print(IQR, UL, LL)

loan_df[(loan_df.person_age  > UL) | (loan_df.person_age  < LL)]

# %%
droplist = loan_df[(loan_df.person_age  > UL) | (loan_df.person_age  < LL)].index.to_list()

# %%
loan_df.drop(droplist, axis = 0, inplace = True)

# %%
loan_df.reset_index(inplace = True)

# %%
loan_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 loan_df
#
# NameError: name 'loan_df' is not defined

# %%
loan_df.drop(['index'], axis=1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 loan_df.drop(['index'], axis=1, inplace = True)
#
# NameError: name 'loan_df' is not defined

# %%
loan_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 loan_df
#
# NameError: name 'loan_df' is not defined

# %%
plt.figure(figsize=(15,5))

plt.subplot(121)
sns.boxplot(loan_df.person_income)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 plt.figure(figsize=(15,5))
#       3 plt.subplot(121)
# ----> 4 sns.boxplot(loan_df.person_income)
#
# NameError: name 'sns' is not defined

# %%
Q1, Q2, Q3 = tuple(loan_df.person_income.quantile(q = [0.25,0.5,0.75]).values)
print(Q1, Q2, Q3)
IQR = Q3-Q1
UL = Q3 + 1.5*IQR
LL = Q1-1.5*IQR

print(IQR, UL, LL)

loan_df[(loan_df.person_income > UL) | (loan_df.person_income  < LL)]

# %%
droplist = loan_df[(loan_df.person_income  > UL) | (loan_df.person_income  < LL)].index.to_list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 droplist = loan_df[(loan_df.person_income  > UL) | (loan_df.person_income  < LL)].index.to_list()
#
# NameError: name 'loan_df' is not defined

# %%
loan_df.drop(droplist, axis = 0, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 loan_df.drop(droplist, axis = 0, inplace = True)
#
# NameError: name 'loan_df' is not defined

# %%
loan_df.reset_index(inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 loan_df.reset_index(inplace = True)
#
# NameError: name 'loan_df' is not defined

# %%
loan_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 loan_df
#
# NameError: name 'loan_df' is not defined

# %%
loan_df.drop(['index'], axis=1, inplace = True)

# %%
loan_df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 29452          40          33000              MORTGAGE                2.0
# 29453          37          90000              MORTGAGE               11.0
# 29454          38         110000              MORTGAGE                5.0
# 29455          36          92000              MORTGAGE               18.0
# 29456          40          52000                  RENT                2.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0               PERSONAL          D      35000          16.02            1
# 1              EDUCATION          B       1000          11.14            0
# 2                MEDICAL          C       5500          12.87            1
# 3                MEDICAL          C      35000          15.23            1
# 4                MEDICAL          C      35000          14.27            1
# ...                  ...        ...        ...            ...          ...
# 29452    HOMEIMPROVEMENT          B       1000          10.99            0
# 29453  DEBTCONSOLIDATION          A       4000           6.62            0
# 29454            MEDICAL          B      16000          11.99            0
# 29455  DEBTCONSOLIDATION          A       4000           7.29            0
# 29456          EDUCATION          F      15000          18.62            1
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.59                         Y
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# ...                    ...                       ...
# 29452                 0.03                         N
# 29453                 0.04                         N
# 29454                 0.15                         N
# 29455                 0.04                         N
# 29456                 0.29                         Y
#
#        cb_person_cred_hist_length
# 0                               3
# 1                               2
# 2                               3
# 3                               2
# 4                               4
# ...                           ...
# 29452                          15
# 29453                          15
# 29454                          13
# 29455                          13
# 29456                          16
#
# [29457 rows x 12 columns]

# %%
plt.figure(figsize=(15,5))

plt.subplot(121)
sns.boxplot(loan_df.person_emp_length)
# Out:
# <AxesSubplot:>
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,5))

plt.subplot(121)
sns.boxplot(loan_df.loan_amnt)
# Out:
# <AxesSubplot:>
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,5))

plt.subplot(121)
sns.boxplot(loan_df.loan_int_rate)
# Out:
# <AxesSubplot:>
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,5))

plt.subplot(121)
sns.boxplot(loan_df.loan_int_rate)
# Out:
# <AxesSubplot:>
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,5))

plt.subplot(121)
sns.boxplot(loan_df.loan_percent_income)
# Out:
# <AxesSubplot:>
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,5))

plt.subplot(121)
sns.boxplot(loan_df.cb_person_cred_hist_length)
# Out:
# <AxesSubplot:>
# <AxesSubplot:>

# %% [markdown]
# ## Data Visualization

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
sns.countplot(x=loan_df.loan_intent)
plt.subplot(122)
plt.pie(loan_df.loan_intent.value_counts().values,labels=loan_df.loan_intent.value_counts().index,autopct='%.2f%%');

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
sns.countplot(x=loan_df.person_home_ownership)
plt.subplot(122)
plt.pie(loan_df.person_home_ownership.value_counts().values,labels=loan_df.person_home_ownership.value_counts().index,autopct='%.2f%%');

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=loan_df.loan_int_rate,y=loan_df.loan_amnt,hue=loan_df.loan_status)
# Out:
# <AxesSubplot:xlabel='loan_int_rate', ylabel='loan_amnt'>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(loan_df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
loan_df.to_csv(r"C:\Users\psath\Downloads\Machine Learning(Loan Prediction)\loan_cleaned.csv", index = False)

# %%
loan_df1 = pd.read_csv(r"C:\Users\psath\Downloads\Machine Learning(Loan Prediction)\loan_cleaned.csv", skipinitialspace = True)

# %%
loan_df1
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 29452          40          33000              MORTGAGE                2.0
# 29453          37          90000              MORTGAGE               11.0
# 29454          38         110000              MORTGAGE                5.0
# 29455          36          92000              MORTGAGE               18.0
# 29456          40          52000                  RENT                2.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0               PERSONAL          D      35000          16.02            1
# 1              EDUCATION          B       1000          11.14            0
# 2                MEDICAL          C       5500          12.87            1
# 3                MEDICAL          C      35000          15.23            1
# 4                MEDICAL          C      35000          14.27            1
# ...                  ...        ...        ...            ...          ...
# 29452    HOMEIMPROVEMENT          B       1000          10.99            0
# 29453  DEBTCONSOLIDATION          A       4000           6.62            0
# 29454            MEDICAL          B      16000          11.99            0
# 29455  DEBTCONSOLIDATION          A       4000           7.29            0
# 29456          EDUCATION          F      15000          18.62            1
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.59                         Y
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# ...                    ...                       ...
# 29452                 0.03                         N
# 29453                 0.04                         N
# 29454                 0.15                         N
# 29455                 0.04                         N
# 29456                 0.29                         Y
#
#        cb_person_cred_hist_length
# 0                               3
# 1                               2
# 2                               3
# 3                               2
# 4                               4
# ...                           ...
# 29452                          15
# 29453                          15
# 29454                          13
# 29455                          13
# 29456                          16
#
# [29457 rows x 12 columns]

# %%
loan_df1 =loan_df1[['person_age', 'person_income', 'person_home_ownership', 'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt', 'loan_int_rate', 'loan_percent_income','cb_person_default_on_file', 'cb_person_cred_hist_length','loan_status']]
loan_df1
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 29452          40          33000              MORTGAGE                2.0
# 29453          37          90000              MORTGAGE               11.0
# 29454          38         110000              MORTGAGE                5.0
# 29455          36          92000              MORTGAGE               18.0
# 29456          40          52000                  RENT                2.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0               PERSONAL          D      35000          16.02
# 1              EDUCATION          B       1000          11.14
# 2                MEDICAL          C       5500          12.87
# 3                MEDICAL          C      35000          15.23
# 4                MEDICAL          C      35000          14.27
# ...                  ...        ...        ...            ...
# 29452    HOMEIMPROVEMENT          B       1000          10.99
# 29453  DEBTCONSOLIDATION          A       4000           6.62
# 29454            MEDICAL          B      16000          11.99
# 29455  DEBTCONSOLIDATION          A       4000           7.29
# 29456          EDUCATION          F      15000          18.62
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.59                         Y
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# ...                    ...                       ...
# 29452                 0.03                         N
# 29453                 0.04                         N
# 29454                 0.15                         N
# 29455                 0.04                         N
# 29456                 0.29                         Y
#
#        cb_person_cred_hist_length  loan_status
# 0                               3            1
# 1                               2            0
# 2                               3            1
# 3                               2            1
# 4                               4            1
# ...                           ...          ...
# 29452                          15            0
# 29453                          15            0
# 29454                          13            0
# 29455                          13            0
# 29456                          16            1
#
# [29457 rows x 12 columns]

# %% [markdown]
# ## Machine Learning Problem
# * Build a system which can take features of Churn Prediction like person_age, person_income, ..... etc.. and predicts the loan default or not.\
# Target Variable: loan default

# %% [markdown]
# ## Identfying the Input and the Output Variables

# %%
y = loan_df1['loan_status']
x = loan_df1[['person_age', 'person_income', 'person_home_ownership', 'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt', 'loan_int_rate', 'loan_percent_income','cb_person_default_on_file', 'cb_person_cred_hist_length']]

# %%
y
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 29452    0
# 29453    0
# 29454    0
# 29455    0
# 29456    1
# Name: loan_status, Length: 29457, dtype: int64

# %%
x
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 29452          40          33000              MORTGAGE                2.0
# 29453          37          90000              MORTGAGE               11.0
# 29454          38         110000              MORTGAGE                5.0
# 29455          36          92000              MORTGAGE               18.0
# 29456          40          52000                  RENT                2.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0               PERSONAL          D      35000          16.02
# 1              EDUCATION          B       1000          11.14
# 2                MEDICAL          C       5500          12.87
# 3                MEDICAL          C      35000          15.23
# 4                MEDICAL          C      35000          14.27
# ...                  ...        ...        ...            ...
# 29452    HOMEIMPROVEMENT          B       1000          10.99
# 29453  DEBTCONSOLIDATION          A       4000           6.62
# 29454            MEDICAL          B      16000          11.99
# 29455  DEBTCONSOLIDATION          A       4000           7.29
# 29456          EDUCATION          F      15000          18.62
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.59                         Y
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# ...                    ...                       ...
# 29452                 0.03                         N
# 29453                 0.04                         N
# 29454                 0.15                         N
# 29455                 0.04                         N
# 29456                 0.29                         Y
#
#        cb_person_cred_hist_length
# 0                               3
# 1                               2
# 2                               3
# 3                               2
# 4                               4
# ...                           ...
# 29452                          15
# 29453                          15
# 29454                          13
# 29455                          13
# 29456                          16
#
# [29457 rows x 11 columns]

# %% [markdown]
# ## Sepearting the Data into Train and Test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (22092, 11) (22092,)
# (7365, 11) (7365,)

# %%
x_train
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 22374          27          62000              MORTGAGE                6.0
# 9053           23          60000              MORTGAGE                7.0
# 2908           25          37000                  RENT                2.0
# 11290          22          69000              MORTGAGE                1.0
# 12555          26          85000              MORTGAGE               10.0
# ...           ...            ...                   ...                ...
# 13123          25          90000              MORTGAGE                7.0
# 19648          34          41600              MORTGAGE               16.0
# 9845           25          65000              MORTGAGE                6.0
# 10799          24          55243              MORTGAGE                6.0
# 2732           24          35000              MORTGAGE                5.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 22374  DEBTCONSOLIDATION          B      15000          10.99
# 9053   DEBTCONSOLIDATION          B       6000           9.45
# 2908             VENTURE          B       3325          11.49
# 11290          EDUCATION          C      17000          15.27
# 12555           PERSONAL          A      12000           6.62
# ...                  ...        ...        ...            ...
# 13123           PERSONAL          A       6000           7.14
# 19648  DEBTCONSOLIDATION          A      17500           6.17
# 9845             MEDICAL          B      15000          11.86
# 10799            MEDICAL          B       2900           9.62
# 2732   DEBTCONSOLIDATION          A       4800           5.42
#
#        loan_percent_income cb_person_default_on_file  \
# 22374                 0.24                         N
# 9053                  0.10                         N
# 2908                  0.09                         N
# 11290                 0.25                         N
# 12555                 0.14                         N
# ...                    ...                       ...
# 13123                 0.07                         N
# 19648                 0.42                         N
# 9845                  0.23                         N
# 10799                 0.04                         N
# 2732                  0.14                         N
#
#        cb_person_cred_hist_length
# 22374                           8
# 9053                            2
# 2908                            3
# 11290                           3
# 12555                           3
# ...                           ...
# 13123                           3
# 19648                           6
# 9845                            3
# 10799                           2
# 2732                            3
#
# [22092 rows x 11 columns]

# %%
x_test
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 11911          23          80000              MORTGAGE                7.0
# 12452          26          62000                  RENT               10.0
# 26464          28          80000                  RENT                2.0
# 22807          35          65000              MORTGAGE                5.0
# 12477          26          84000              MORTGAGE               10.0
# ...           ...            ...                   ...                ...
# 17328          32          17000                   OWN                0.0
# 28458          36          95000                  RENT                3.0
# 25002          29          65000                  RENT                1.0
# 3526           21          19000                  RENT                3.0
# 22217          29          60000                   OWN                0.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 11911          EDUCATION          B      15000          12.42
# 12452            VENTURE          B      12000          12.69
# 26464  DEBTCONSOLIDATION          B      15000          11.48
# 22807  DEBTCONSOLIDATION          B      25000           9.51
# 12477           PERSONAL          B       4925           9.96
# ...                  ...        ...        ...            ...
# 17328           PERSONAL          D       3200          14.84
# 28458            VENTURE          A       7375           8.94
# 25002          EDUCATION          B      12800           9.45
# 3526           EDUCATION          C       4000          14.35
# 22217    HOMEIMPROVEMENT          D      16000          16.00
#
#        loan_percent_income cb_person_default_on_file  \
# 11911                 0.19                         N
# 12452                 0.19                         N
# 26464                 0.19                         N
# 22807                 0.38                         N
# 12477                 0.06                         N
# ...                    ...                       ...
# 17328                 0.19                         N
# 28458                 0.08                         N
# 25002                 0.20                         N
# 3526                  0.21                         Y
# 22217                 0.27                         Y
#
#        cb_person_cred_hist_length
# 11911                           2
# 12452                           3
# 26464                           5
# 22807                          10
# 12477                           3
# ...                           ...
# 17328                           7
# 28458                          15
# 25002                          10
# 3526                            3
# 22217                           8
#
# [7365 rows x 11 columns]

# %%
print(x_train.shape, y_train.shape)

print(x_test.shape, y_test.shape)
# Out:
# (22092, 11) (22092,)
# (7365, 11) (7365,)

# %% [markdown]
# ## Separating Categorical and Numerical Columns

# %%
x_train.head(25)
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 22374          27          62000              MORTGAGE                6.0
# 9053           23          60000              MORTGAGE                7.0
# 2908           25          37000                  RENT                2.0
# 11290          22          69000              MORTGAGE                1.0
# 12555          26          85000              MORTGAGE               10.0
# 19152          29          38000              MORTGAGE                5.0
# 28785          40          60000                  RENT                3.0
# 9828           24          65000              MORTGAGE                3.0
# 4595           21          32000                  RENT                3.0
# 21738          28          57000                   OWN                7.0
# 624            23          84000                  RENT                7.0
# 17147          23          72250                  RENT                7.0
# 11413          23          75000              MORTGAGE                7.0
# 27886          36          32000              MORTGAGE                6.0
# 9533           23          60626                  RENT                4.0
# 22915          34          67000              MORTGAGE                4.0
# 2735           23          35000              MORTGAGE                4.0
# 15668          25          16000                  RENT                0.0
# 27185          35          29400                  RENT                0.0
# 1102           22          44000                  RENT                1.0
# 10061          22          66000              MORTGAGE                4.0
# 28268          39          30000                  RENT                3.0
# 8960           25          60000                   OWN                3.0
# 18563          28          50000                  RENT                5.0
# 16551          24          91000              MORTGAGE                5.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 22374  DEBTCONSOLIDATION          B      15000          10.99
# 9053   DEBTCONSOLIDATION          B       6000           9.45
# 2908             VENTURE          B       3325          11.49
# 11290          EDUCATION          C      17000          15.27
# 12555           PERSONAL          A      12000           6.62
# 19152          EDUCATION          A       8000           8.59
# 28785    HOMEIMPROVEMENT          D      10000          15.95
# 9828   DEBTCONSOLIDATION          C       7000          13.61
# 4595           EDUCATION          A       5000           7.68
# 21738           PERSONAL          B       3500          11.83
# 624             PERSONAL          B      20000          11.11
# 17147            MEDICAL          B      30000          10.65
# 11413          EDUCATION          B       7100           9.25
# 27886  DEBTCONSOLIDATION          B      12000          10.37
# 9533           EDUCATION          A       8625           7.90
# 22915          EDUCATION          A       7000           7.51
# 2735             VENTURE          A       3825           7.49
# 15668           PERSONAL          A       3200           9.32
# 27185          EDUCATION          B       6150          12.21
# 1102           EDUCATION          E      16000          16.35
# 10061  DEBTCONSOLIDATION          A       2700           6.76
# 28268           PERSONAL          B       6000          10.75
# 8960            PERSONAL          C      16000          13.57
# 18563           PERSONAL          C      12000          13.11
# 16551  DEBTCONSOLIDATION          A      15000           7.88
#
#        loan_percent_income cb_person_default_on_file  \
# 22374                 0.24                         N
# 9053                  0.10                         N
# 2908                  0.09                         N
# 11290                 0.25                         N
# 12555                 0.14                         N
# 19152                 0.21                         N
# 28785                 0.17                         N
# 9828                  0.11                         Y
# 4595                  0.16                         N
# 21738                 0.06                         N
# 624                   0.24                         N
# 17147                 0.35                         N
# 11413                 0.09                         N
# 27886                 0.38                         N
# 9533                  0.14                         N
# 22915                 0.10                         N
# 2735                  0.11                         N
# 15668                 0.20                         N
# 27185                 0.21                         N
# 1102                  0.36                         N
# 10061                 0.04                         N
# 28268                 0.20                         N
# 8960                  0.27                         Y
# 18563                 0.24                         N
# 16551                 0.16                         N
#
#        cb_person_cred_hist_length
# 22374                           8
# 9053                            2
# 2908                            3
# 11290                           3
# 12555                           3
# 19152                           6
# 28785                          14
# 9828                            3
# 4595                            4
# 21738                           6
# 624                             4
# 17147                           2
# 11413                           2
# 27886                          11
# 9533                            4
# 22915                           9
# 2735                            4
# 15668                           4
# 27185                          10
# 1102                            3
# 10061                           3
# 28268                          14
# 8960                            4
# 18563                          10
# 16551                           2

# %%
x_train.dtypes
# Out:
# person_age                      int64
# person_income                   int64
# person_home_ownership          object
# person_emp_length             float64
# loan_intent                    object
# loan_grade                     object
# loan_amnt                       int64
# loan_int_rate                 float64
# loan_percent_income           float64
# cb_person_default_on_file      object
# cb_person_cred_hist_length      int64
# dtype: object

# %% [markdown]
# ## Seperating Label Encoding and One Hot Encoding Categorical Data

# %%
x_train_cat_ord = x_train[['loan_grade']]
x_train_cat_ohe = x_train[['person_home_ownership','loan_intent']]

# %%
x_train_cat_ohe
# Out:
#       person_home_ownership        loan_intent
# 22374              MORTGAGE  DEBTCONSOLIDATION
# 9053               MORTGAGE  DEBTCONSOLIDATION
# 2908                   RENT            VENTURE
# 11290              MORTGAGE          EDUCATION
# 12555              MORTGAGE           PERSONAL
# ...                     ...                ...
# 13123              MORTGAGE           PERSONAL
# 19648              MORTGAGE  DEBTCONSOLIDATION
# 9845               MORTGAGE            MEDICAL
# 10799              MORTGAGE            MEDICAL
# 2732               MORTGAGE  DEBTCONSOLIDATION
#
# [22092 rows x 2 columns]

# %%
x_train_cat_ord
# Out:
#       loan_grade
# 22374          B
# 9053           B
# 2908           B
# 11290          C
# 12555          A
# ...          ...
# 13123          A
# 19648          A
# 9845           B
# 10799          B
# 2732           A
#
# [22092 rows x 1 columns]

# %%
x_train_num = x_train.select_dtypes(include=['int64', 'float64'])

x_train_num.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 22374          27          62000                6.0      15000          10.99
# 9053           23          60000                7.0       6000           9.45
# 2908           25          37000                2.0       3325          11.49
# 11290          22          69000                1.0      17000          15.27
# 12555          26          85000               10.0      12000           6.62
#
#        loan_percent_income  cb_person_cred_hist_length
# 22374                 0.24                           8
# 9053                  0.10                           2
# 2908                  0.09                           3
# 11290                 0.25                           3
# 12555                 0.14                           3

# %% [markdown]
# ## Scaling the Numerical Features

# %%
x_train_num.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 22374          27          62000                6.0      15000          10.99
# 9053           23          60000                7.0       6000           9.45
# 2908           25          37000                2.0       3325          11.49
# 11290          22          69000                1.0      17000          15.27
# 12555          26          85000               10.0      12000           6.62
#
#        loan_percent_income  cb_person_cred_hist_length
# 22374                 0.24                           8
# 9053                  0.10                           2
# 2908                  0.09                           3
# 11290                 0.25                           3
# 12555                 0.14                           3

# %%
# scaling the numerical features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# column names are (annoyingly) lost after Scaling
# (i.e. the dataframe is converted to a numpy ndarray)

x_train_num_transformed = pd.DataFrame(scaler.fit_transform(x_train_num), 
                                    columns = x_train_num.columns, 
                                    index = x_train_num.index)

x_train_num_transformed.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 22374    0.064404       0.145265           0.357602   0.960876      -0.007202
# 9053    -0.823463       0.071120           0.617220  -0.539230      -0.505404
# 2908    -0.379529      -0.781554          -0.680867  -0.985095       0.154552
# 11290   -1.045429       0.404775          -0.940484   1.294233       1.377412
# 12555   -0.157563       0.997939           1.396071   0.460841      -1.420932
#
#        loan_percent_income  cb_person_cred_hist_length
# 22374             0.606842                    0.831205
# 9053             -0.698539                   -0.982931
# 2908             -0.791781                   -0.680575
# 11290             0.700084                   -0.680575
# 12555            -0.325573                   -0.680575

# %%
x_train_num_transformed.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  2.209200e+04   2.209200e+04       2.209200e+04  2.209200e+04
# mean   2.463678e-16   2.187077e-17       1.093539e-16  7.976399e-17
# std    1.000023e+00   1.000023e+00       1.000023e+00  1.000023e+00
# min   -1.489362e+00  -2.001989e+00      -1.200101e+00 -1.455962e+00
# 25%   -8.234626e-01  -7.630174e-01      -6.808666e-01 -7.059089e-01
# 50%   -3.795295e-01  -1.513167e-01      -1.616321e-01 -2.058734e-01
# 75%    5.083368e-01   6.224660e-01       6.172197e-01  4.608405e-01
# max    2.949969e+00   3.007283e+00       3.073282e+01  4.294446e+00
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length
# count   2.209200e+04         2.209200e+04                2.209200e+04
# mean   -7.574362e-17        -2.183861e-16               -1.016348e-16
# std     1.000023e+00         1.000023e+00                1.000023e+00
# min    -1.809141e+00        -1.537713e+00               -9.829306e-01
# 25%    -8.159718e-01        -7.917807e-01               -6.805746e-01
# 50%    -7.201904e-03        -2.323315e-01               -3.782187e-01
# 75%     6.948104e-01         5.136008e-01                5.288492e-01
# max     3.949301e+00         6.108093e+00                3.552409e+00

# %% [markdown]
# ## Applying OneHotEncoding on Categorical Columns

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)

# column names are (annoyingly) lost after OneHotEncoding
# (i.e. the dataframe is converted to a numpy ndarray)

x_train_cat_ohe_trans = pd.DataFrame(encoder.fit_transform(x_train_cat_ohe), 
                               columns=encoder.get_feature_names_out(x_train_cat_ohe.columns), 
                               index = x_train_cat_ohe.index)

x_train_cat_ohe_trans.head()
# Out:
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 22374                          0.0                        0.0
# 9053                           0.0                        0.0
# 2908                           0.0                        0.0
# 11290                          0.0                        0.0
# 12555                          0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 22374                         0.0                    0.0
# 9053                          0.0                    0.0
# 2908                          1.0                    0.0
# 11290                         0.0                    1.0
# 12555                         0.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 22374                          0.0                  0.0                   0.0
# 9053                           0.0                  0.0                   0.0
# 2908                           0.0                  0.0                   0.0
# 11290                          0.0                  0.0                   0.0
# 12555                          0.0                  0.0                   1.0
#
#        loan_intent_VENTURE
# 22374                  0.0
# 9053                   0.0
# 2908                   1.0
# 11290                  0.0
# 12555                  0.0

# %% [markdown]
# ## Apply Label Encoding

# %%
x_train_cat_le = pd.DataFrame(index=x_train_cat_ord.index)

x_train_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [22374, 9053, 2908, 11290, 12555]

# %%
x_train_cat_ord.loan_grade.unique()
# Out:
# array(['B', 'C', 'A', 'D', 'E', 'F', 'G'], dtype=object)

# %%
grade_encoder = { 'A' : 1,'B' : 3, 'C' : 2, 'D' : 4, 'E' : 5,'F' : 6, 'G' : 7}

x_train_cat_le['loan_grade'] = x_train_cat_ord['loan_grade'].apply(lambda x : grade_encoder[x])

x_train_cat_le.head()
# Out:
#        loan_grade
# 22374           3
# 9053            3
# 2908            3
# 11290           2
# 12555           1

# %%
loan_df1.groupby(['loan_grade'])['loan_amnt'].mean()
# Out:
# loan_grade
# A     8342.261661
# B     9577.391466
# C     8933.348912
# D    10450.396583
# E    12214.038687
# F    14244.497608
# G    16941.101695
# Name: loan_amnt, dtype: float64

# %% [markdown]
# ## Concatenating Numerical and Categorical Columns

# %%
x_train_transformed = pd.concat([x_train_num_transformed, x_train_cat_ohe_trans, x_train_cat_le], axis=1)

x_train_transformed.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 22374    0.064404       0.145265           0.357602   0.960876      -0.007202
# 9053    -0.823463       0.071120           0.617220  -0.539230      -0.505404
# 2908    -0.379529      -0.781554          -0.680867  -0.985095       0.154552
# 11290   -1.045429       0.404775          -0.940484   1.294233       1.377412
# 12555   -0.157563       0.997939           1.396071   0.460841      -1.420932
#
#        loan_percent_income  cb_person_cred_hist_length  \
# 22374             0.606842                    0.831205
# 9053             -0.698539                   -0.982931
# 2908             -0.791781                   -0.680575
# 11290             0.700084                   -0.680575
# 12555            -0.325573                   -0.680575
#
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 22374                          0.0                        0.0
# 9053                           0.0                        0.0
# 2908                           0.0                        0.0
# 11290                          0.0                        0.0
# 12555                          0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 22374                         0.0                    0.0
# 9053                          0.0                    0.0
# 2908                          1.0                    0.0
# 11290                         0.0                    1.0
# 12555                         0.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 22374                          0.0                  0.0                   0.0
# 9053                           0.0                  0.0                   0.0
# 2908                           0.0                  0.0                   0.0
# 11290                          0.0                  0.0                   0.0
# 12555                          0.0                  0.0                   1.0
#
#        loan_intent_VENTURE  loan_grade
# 22374                  0.0           3
# 9053                   0.0           3
# 2908                   1.0           3
# 11290                  0.0           2
# 12555                  0.0           1

# %% [markdown]
# ## Preparing Test Data

# %%
x_test.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 11911          23          80000              MORTGAGE                7.0
# 12452          26          62000                  RENT               10.0
# 26464          28          80000                  RENT                2.0
# 22807          35          65000              MORTGAGE                5.0
# 12477          26          84000              MORTGAGE               10.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 11911          EDUCATION          B      15000          12.42
# 12452            VENTURE          B      12000          12.69
# 26464  DEBTCONSOLIDATION          B      15000          11.48
# 22807  DEBTCONSOLIDATION          B      25000           9.51
# 12477           PERSONAL          B       4925           9.96
#
#        loan_percent_income cb_person_default_on_file  \
# 11911                 0.19                         N
# 12452                 0.19                         N
# 26464                 0.19                         N
# 22807                 0.38                         N
# 12477                 0.06                         N
#
#        cb_person_cred_hist_length
# 11911                           2
# 12452                           3
# 26464                           5
# 22807                          10
# 12477                           3

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7365 entries, 11911 to 22217
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  7365 non-null   int64
#  1   person_income               7365 non-null   int64
#  2   person_home_ownership       7365 non-null   object
#  3   person_emp_length           7365 non-null   float64
#  4   loan_intent                 7365 non-null   object
#  5   loan_grade                  7365 non-null   object
#  6   loan_amnt                   7365 non-null   int64
#  7   loan_int_rate               7365 non-null   float64
#  8   loan_percent_income         7365 non-null   float64
#  9   cb_person_default_on_file   7365 non-null   object
#  10  cb_person_cred_hist_length  7365 non-null   int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 690.5+ KB

# %%
x_test_cat_ord = x_test[['loan_grade']]
x_test_cat_ohe = x_test[['person_home_ownership','loan_intent']]

# %%
x_test_cat_ord
# Out:
#       loan_grade
# 11911          B
# 12452          B
# 26464          B
# 22807          B
# 12477          B
# ...          ...
# 17328          D
# 28458          A
# 25002          B
# 3526           C
# 22217          D
#
# [7365 rows x 1 columns]

# %%
x_test_num = x_test.select_dtypes(include=['int64', 'float64'])

x_test_num.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 11911          23          80000                7.0      15000          12.42
# 12452          26          62000               10.0      12000          12.69
# 26464          28          80000                2.0      15000          11.48
# 22807          35          65000                5.0      25000           9.51
# 12477          26          84000               10.0       4925           9.96
#
#        loan_percent_income  cb_person_cred_hist_length
# 11911                 0.19                           2
# 12452                 0.19                           3
# 26464                 0.19                           5
# 22807                 0.38                          10
# 12477                 0.06                           3

# %%
x_test_num_transformed = pd.DataFrame(scaler.transform(x_test_num), 
                                   columns = x_test_num.columns, 
                                   index = x_test_num.index)

x_test_num_transformed.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 11911   -0.823463       0.812575           0.617220   0.960876       0.455415
# 12452   -0.157563       0.145265           1.396071   0.460841       0.542762
# 26464    0.286370       0.812575          -0.680867   0.960876       0.151317
# 22807    1.840136       0.256484           0.097985   2.627661      -0.485994
# 12477   -0.157563       0.960866           1.396071  -0.718410      -0.340415
#
#        loan_percent_income  cb_person_cred_hist_length
# 11911             0.140635                   -0.982931
# 12452             0.140635                   -0.680575
# 26464             0.140635                   -0.075863
# 22807             1.912224                    1.435917
# 12477            -1.071505                   -0.680575

# %%
x_test_cat_ohe_trans = pd.DataFrame(encoder.transform(x_test_cat_ohe), 
                               columns=encoder.get_feature_names_out(x_test_cat_ohe.columns), 
                               index = x_test_cat_ohe.index)

x_test_cat_ohe_trans.head()
# Out:
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 11911                          0.0                        0.0
# 12452                          0.0                        0.0
# 26464                          0.0                        0.0
# 22807                          0.0                        0.0
# 12477                          0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 11911                         0.0                    1.0
# 12452                         1.0                    0.0
# 26464                         1.0                    0.0
# 22807                         0.0                    0.0
# 12477                         0.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 11911                          0.0                  0.0                   0.0
# 12452                          0.0                  0.0                   0.0
# 26464                          0.0                  0.0                   0.0
# 22807                          0.0                  0.0                   0.0
# 12477                          0.0                  0.0                   1.0
#
#        loan_intent_VENTURE
# 11911                  0.0
# 12452                  1.0
# 26464                  0.0
# 22807                  0.0
# 12477                  0.0

# %%
x_test_cat_le = pd.DataFrame(index = x_test_cat_ord.index)

x_test_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [11911, 12452, 26464, 22807, 12477]

# %%
x_test_cat_le['loan_grade'] = x_test_cat_ord['loan_grade'].apply(lambda x : grade_encoder[x])

# %%
x_test_cat_le
# Out:
#        loan_grade
# 11911           3
# 12452           3
# 26464           3
# 22807           3
# 12477           3
# ...           ...
# 17328           4
# 28458           1
# 25002           3
# 3526            2
# 22217           4
#
# [7365 rows x 1 columns]

# %% [markdown]
# ## Concatenating Numerical and Categorical Columns

# %%
x_test_transformed = pd.concat([x_test_num_transformed, x_test_cat_ohe_trans, x_test_cat_le], axis=1)

x_test_transformed.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 11911   -0.823463       0.812575           0.617220   0.960876       0.455415
# 12452   -0.157563       0.145265           1.396071   0.460841       0.542762
# 26464    0.286370       0.812575          -0.680867   0.960876       0.151317
# 22807    1.840136       0.256484           0.097985   2.627661      -0.485994
# 12477   -0.157563       0.960866           1.396071  -0.718410      -0.340415
#
#        loan_percent_income  cb_person_cred_hist_length  \
# 11911             0.140635                   -0.982931
# 12452             0.140635                   -0.680575
# 26464             0.140635                   -0.075863
# 22807             1.912224                    1.435917
# 12477            -1.071505                   -0.680575
#
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 11911                          0.0                        0.0
# 12452                          0.0                        0.0
# 26464                          0.0                        0.0
# 22807                          0.0                        0.0
# 12477                          0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 11911                         0.0                    1.0
# 12452                         1.0                    0.0
# 26464                         1.0                    0.0
# 22807                         0.0                    0.0
# 12477                         0.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 11911                          0.0                  0.0                   0.0
# 12452                          0.0                  0.0                   0.0
# 26464                          0.0                  0.0                   0.0
# 22807                          0.0                  0.0                   0.0
# 12477                          0.0                  0.0                   1.0
#
#        loan_intent_VENTURE  loan_grade
# 11911                  0.0           3
# 12452                  1.0           3
# 26464                  0.0           3
# 22807                  0.0           3
# 12477                  0.0           3

# %% [markdown]
# ## Logestic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(x_train_transformed, y_train)
# Out:
# LogisticRegression()

# %%
y_test_pred = classifier.predict(x_test_transformed)

# %%
from sklearn import metrics
# from sklearn.metrics import accuracy score

a = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy', a)
# Out:
# Accuracy 0.8475220638153428

# %% [markdown]
# ## KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train_transformed, y_train)
y_test_pred = classifier.predict(x_test_transformed)
b = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy', b)
# Out:
# KNeighborsClassifier()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [78], in <cell line: 4>()
#       2 classifier = KNeighborsClassifier(n_neighbors=5)
#       3 classifier.fit(x_train_transformed, y_train)
# ----> 4 y_test_pred = classifier.predict(x_test_transformed)
#       5 b = metrics.accuracy_score(y_test, y_test_pred)
#       6 print('Accuracy', b)
#
# File ~\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:234, in KNeighborsClassifier.predict(self, X)
#     218 """Predict the class labels for the provided data.
#     219
#     220 Parameters
#    (...)
#     229     Class labels for each data sample.
#     230 """
#     231 if self.weights == "uniform":
#     232     # In that case, we do not need the distances to perform
#     233     # the weighting so we do not compute them.
# --> 234     neigh_ind = self.kneighbors(X, return_distance=False)
#     235     neigh_dist = None
#     236 else:
#
# File ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py:824, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     817 use_pairwise_distances_reductions = (
#     818     self._fit_method == "brute"
#     819     and ArgKmin.is_usable_for(
#     820         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     821     )
#     822 )
#     823 if use_pairwise_distances_reductions:
# --> 824     results = ArgKmin.compute(
#     825         X=X,
#     826         Y=self._fit_X,
#     827         k=n_neighbors,
#     828         metric=self.effective_metric_,
#     829         metric_kwargs=self.effective_metric_params_,
#     830         strategy="auto",
#     831         return_distance=return_distance,
#     832     )
#     834 elif (
#     835     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     836 ):
#     837     results = _kneighbors_from_graph(
#     838         X, n_neighbors=n_neighbors, return_distance=return_distance
#     839     )
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py:277, in ArgKmin.compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     196 """Compute the argkmin reduction.
#     197
#     198 Parameters
#    (...)
#     274 returns.
#     275 """
#     276 if X.dtype == Y.dtype == np.float64:
# --> 277     return ArgKmin64.compute(
#     278         X=X,
#     279         Y=Y,
#     280         k=k,
#     281         metric=metric,
#     282         chunk_size=chunk_size,
#     283         metric_kwargs=metric_kwargs,
#     284         strategy=strategy,
#     285         return_distance=return_distance,
#     286     )
#     288 if X.dtype == Y.dtype == np.float32:
#     289     return ArgKmin32.compute(
#     290         X=X,
#     291         Y=Y,
#    (...)
#     297         return_distance=return_distance,
#     298     )
#
# File sklearn\metrics\_pairwise_distances_reduction\_argkmin.pyx:95, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute()
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py:139, in threadpool_limits(limits, user_api)
#     137     return controller.limit(limits=limits, user_api=user_api)
#     138 else:
# --> 139     return threadpoolctl.threadpool_limits(limits=limits, user_api=user_api)
#
# File ~\anaconda3\lib\site-packages\threadpoolctl.py:171, in threadpool_limits.__init__(self, limits, user_api)
#     167 def __init__(self, limits=None, user_api=None):
#     168     self._limits, self._user_api, self._prefixes = \
#     169         self._check_params(limits, user_api)
# --> 171     self._original_info = self._set_threadpool_limits()
#
# File ~\anaconda3\lib\site-packages\threadpoolctl.py:268, in threadpool_limits._set_threadpool_limits(self)
#     265 if self._limits is None:
#     266     return None
# --> 268 modules = _ThreadpoolInfo(prefixes=self._prefixes,
#     269                           user_api=self._user_api)
#     270 for module in modules:
#     271     # self._limits is a dict {key: num_threads} where key is either
#     272     # a prefix or a user_api. If a module matches both, the limit
#     273     # corresponding to the prefix is chosed.
#     274     if module.prefix in self._limits:
#
# File ~\anaconda3\lib\site-packages\threadpoolctl.py:340, in _ThreadpoolInfo.__init__(self, user_api, prefixes, modules)
#     337     self.user_api = [] if user_api is None else user_api
#     339     self.modules = []
# --> 340     self._load_modules()
#     341     self._warn_if_incompatible_openmp()
#     342 else:
#
# File ~\anaconda3\lib\site-packages\threadpoolctl.py:373, in _ThreadpoolInfo._load_modules(self)
#     371     self._find_modules_with_dyld()
#     372 elif sys.platform == "win32":
# --> 373     self._find_modules_with_enum_process_module_ex()
#     374 else:
#     375     self._find_modules_with_dl_iterate_phdr()
#
# File ~\anaconda3\lib\site-packages\threadpoolctl.py:485, in _ThreadpoolInfo._find_modules_with_enum_process_module_ex(self)
#     482         filepath = buf.value
#     484         # Store the module if it is supported and selected
# --> 485         self._make_module_from_path(filepath)
#     486 finally:
#     487     kernel_32.CloseHandle(h_process)
#
# File ~\anaconda3\lib\site-packages\threadpoolctl.py:515, in _ThreadpoolInfo._make_module_from_path(self, filepath)
#     513 if prefix in self.prefixes or user_api in self.user_api:
#     514     module_class = globals()[module_class]
# --> 515     module = module_class(filepath, prefix, user_api, internal_api)
#     516     self.modules.append(module)
#
# File ~\anaconda3\lib\site-packages\threadpoolctl.py:606, in _Module.__init__(self, filepath, prefix, user_api, internal_api)
#     604 self.internal_api = internal_api
#     605 self._dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
# --> 606 self.version = self.get_version()
#     607 self.num_threads = self.get_num_threads()
#     608 self._get_extra_info()
#
# File ~\anaconda3\lib\site-packages\threadpoolctl.py:646, in _OpenBLASModule.get_version(self)
#     643 get_config = getattr(self._dynlib, "openblas_get_config",
#     644                      lambda: None)
#     645 get_config.restype = ctypes.c_char_p
# --> 646 config = get_config().split()
#     647 if config[0] == b"OpenBLAS":
#     648     return config[1].decode("utf-8")
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %% [markdown]
# ## DT Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(x_train_transformed, y_train)

y_test_pred = classifier.predict(x_test_transformed)

c = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy', c)
# Out:
# DecisionTreeClassifier()
# Accuracy 0.8904276985743381

# %% [markdown]
# ## Support Vector Classifier

# %%
from sklearn.svm import SVC
classifier = SVC()
classifier.fit(x_train_transformed, y_train)

y_test_pred = classifier.predict(x_test_transformed)

d = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy', d)
# Out:
# SVC()
# Accuracy 0.9026476578411405

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(x_train_transformed, y_train)

y_test_pred = classifier.predict(x_test_transformed)

e = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy', e)
# Out:
# RandomForestClassifier()
# Accuracy 0.9311608961303462

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
classifier = GradientBoostingClassifier()
classifier.fit(x_train_transformed, y_train)

y_test_pred = classifier.predict(x_test_transformed)

f = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy', f)
# Out:
# GradientBoostingClassifier()
# Accuracy 0.9207060420909708

# %% [markdown]
# ## ADA Boost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
classifier = AdaBoostClassifier()
classifier.fit(x_train_transformed, y_train)

y_test_pred = classifier.predict(x_test_transformed)

g = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy', g)
# Out:
# AdaBoostClassifier()
# Accuracy 0.8837746096401901

# %% [markdown]
# ## Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier
classifier = BaggingClassifier()
classifier.fit(x_train_transformed, y_train)

y_test_pred = classifier.predict(x_test_transformed)

h = metrics.accuracy_score(y_test, y_test_pred)
print('Accuracy', h)
# Out:
# BaggingClassifier()
# Accuracy 0.9285811269517991

# %%
df_data = [['Logistic Regression', a ],
                   ['Decision Tree Classifier',c],
                   ['Support Vector Classifier',d],
                   ['Random Forest Classifier ',e],
                ['Gradient Boosting Decision Tree Clasifier', f],
          ['Adaptive Boosting Clasifier', g],
          ['BaggingClassifier', h]]

data = pd.DataFrame(df_data, columns = ['Algorithm','Accuracy'])

# %%
data
# Out:
#                                    Algorithm  Accuracy
# 0                        Logistic Regression  0.847522
# 1                   Decision Tree Classifier  0.890428
# 2                  Support Vector Classifier  0.902648
# 3                  Random Forest Classifier   0.931161
# 4  Gradient Boosting Decision Tree Clasifier  0.920706
# 5                Adaptive Boosting Clasifier  0.883775
# 6                          BaggingClassifier  0.928581

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation = 45)
sns.barplot(x = data.Accuracy, y = data.Algorithm, ci = False)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
# <AxesSubplot:xlabel='Accuracy', ylabel='Algorithm'>

# %% [markdown]
# ## Conclusion
# * From The Above Graph `Random Forest Classifier` is more accurate with 93.11% and second is `BaggingClassifier` with 92.8% and third is `Gradient Boosting Decision Tree Clasifier` is with 92.07%
# * So Finally `Random Forest Classifier` is the best algorithm
